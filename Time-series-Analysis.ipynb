# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
google=pd.read_csv("C:\\Users\\guriv\\Downloads\\google.csv")

# %%
google
# Out:
#             Date         Open         High          Low        Close  \
# 0     2004-08-19    49.813290    51.835709    47.800831    49.982655
# 1     2004-08-20    50.316402    54.336334    50.062355    53.952770
# 2     2004-08-23    55.168217    56.528118    54.321388    54.495735
# 3     2004-08-24    55.412300    55.591629    51.591621    52.239197
# 4     2004-08-25    52.284027    53.798351    51.746044    52.802086
# ...          ...          ...          ...          ...          ...
# 4466  2022-05-16  2307.679932  2332.149902  2286.699951  2295.850098
# 4467  2022-05-17  2344.550049  2344.550049  2306.750000  2334.030029
# 4468  2022-05-18  2304.750000  2313.913086  2242.840088  2248.020020
# 4469  2022-05-19  2236.820068  2271.750000  2209.360107  2214.909912
# 4470  2022-05-20  2241.709961  2251.000000  2127.459961  2186.260010
#
#         Adj Close    Volume
# 0       49.982655  44871361
# 1       53.952770  22942874
# 2       54.495735  18342897
# ...

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4471 entries, 0 to 4470
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4471 non-null   object
#  1   Open       4471 non-null   float64
#  2   High       4471 non-null   float64
#  3   Low        4471 non-null   float64
#  4   Close      4471 non-null   float64
#  5   Adj Close  4471 non-null   float64
#  6   Volume     4471 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 244.6+ KB

# %%
google["Date"]=pd.to_datetime(google["Date"])

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4471 entries, 0 to 4470
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4471 non-null   datetime64[ns]
#  1   Open       4471 non-null   float64
#  2   High       4471 non-null   float64
#  3   Low        4471 non-null   float64
#  4   Close      4471 non-null   float64
#  5   Adj Close  4471 non-null   float64
#  6   Volume     4471 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 244.6 KB

# %%
google.set_index("Date", inplace=True)

# %%
google
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2004-08-19    49.813290    51.835709    47.800831    49.982655    49.982655
# 2004-08-20    50.316402    54.336334    50.062355    53.952770    53.952770
# 2004-08-23    55.168217    56.528118    54.321388    54.495735    54.495735
# 2004-08-24    55.412300    55.591629    51.591621    52.239197    52.239197
# 2004-08-25    52.284027    53.798351    51.746044    52.802086    52.802086
# ...                 ...          ...          ...          ...          ...
# 2022-05-16  2307.679932  2332.149902  2286.699951  2295.850098  2295.850098
# 2022-05-17  2344.550049  2344.550049  2306.750000  2334.030029  2334.030029
# 2022-05-18  2304.750000  2313.913086  2242.840088  2248.020020  2248.020020
# 2022-05-19  2236.820068  2271.750000  2209.360107  2214.909912  2214.909912
# 2022-05-20  2241.709961  2251.000000  2127.459961  2186.260010  2186.260010
#
#               Volume
# Date
# ...

# %%
google["month"]=google.index.month_name()

# %%
google.index.day()
# Out:
# Index([19, 20, 23, 24, 25, 26, 27, 30, 31,  1,
#        ...
#         9, 10, 11, 12, 13, 16, 17, 18, 19, 20],
#       dtype='int32', name='Date', length=4471)

# %%
google["day_name"]=google.index.day_name()

# %%
google
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2004-08-19    49.813290    51.835709    47.800831    49.982655    49.982655
# 2004-08-20    50.316402    54.336334    50.062355    53.952770    53.952770
# 2004-08-23    55.168217    56.528118    54.321388    54.495735    54.495735
# 2004-08-24    55.412300    55.591629    51.591621    52.239197    52.239197
# 2004-08-25    52.284027    53.798351    51.746044    52.802086    52.802086
# ...                 ...          ...          ...          ...          ...
# 2022-05-16  2307.679932  2332.149902  2286.699951  2295.850098  2295.850098
# 2022-05-17  2344.550049  2344.550049  2306.750000  2334.030029  2334.030029
# 2022-05-18  2304.750000  2313.913086  2242.840088  2248.020020  2248.020020
# 2022-05-19  2236.820068  2271.750000  2209.360107  2214.909912  2214.909912
# 2022-05-20  2241.709961  2251.000000  2127.459961  2186.260010  2186.260010
#
#               Volume   month   day_name
# Date
# ...

# %%
#filtering

# %%
google.loc["2004-11"]
# Out:
#                  Open        High        Low      Close  Adj Close    Volume  \
# Date
# 2004-11-01  96.413620   98.465927  95.277878  97.648987  97.648987  24541444
# 2004-11-02  99.018852   99.252975  96.309013  97.071152  97.071152  22777657
# 2004-11-03  98.719971  100.423592  95.018845  95.477127  95.477127  27881517
# 2004-11-04  93.868156   94.844498  91.332664  92.005142  92.005142  28927221
# 2004-11-05  90.650223   90.809624  83.960297  84.358803  84.358803  39814879
# 2004-11-08  85.145851   87.392433  84.383713  85.952827  85.952827  22467499
# 2004-11-09  86.724937   87.272881  82.326424  84.035019  84.035019  22211343
# 2004-11-10  85.016335   85.937881  82.854439  83.616585  83.616585  21367793
# 2004-11-11  84.249214   91.531914  83.472122  91.168282  91.168282  30083339
# 2004-11-12  92.269150   94.545624  88.368774  90.660187  90.660187  33617737
# 2004-11-15  89.888077   93.808380  89.041252  92.089828  92.089828  23892219
# ...

# %%
pd.date_range(start="2004-1-6", end="2017-1-6", freq=pd.DateOffset(years=1))
# Out:
# DatetimeIndex(['2004-01-06', '2005-01-06', '2006-01-06', '2007-01-06',
#                '2008-01-06', '2009-01-06', '2010-01-06', '2011-01-06',
#                '2012-01-06', '2013-01-06', '2014-01-06', '2015-01-06',
#                '2016-01-06', '2017-01-06'],
#               dtype='datetime64[ns]', freq='<DateOffset: years=1>')

# %%
google[google.index.isin(pd.date_range(start="2004-1-6", end="2017-1-6", freq=pd.DateOffset(years=1)))]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2005-01-06   97.175758   97.584229   93.509506   93.922951   93.922951
# 2006-01-06  227.581970  234.371521  225.773743  231.960556  231.960556
# 2009-01-06  165.868286  169.763687  162.585587  166.406265  166.406265
# 2010-01-06  311.761444  311.761444  302.047852  302.994293  302.994293
# 2011-01-06  304.199799  308.060303  303.885956  305.604523  305.604523
# 2012-01-06  328.344299  328.767700  323.681763  323.796326  323.796326
# 2014-01-06  554.426880  557.340942  551.154114  556.573853  556.573853
# 2015-01-06  513.589966  514.761719  499.678131  500.585632  500.585632
# 2016-01-06  730.000000  747.179993  728.919983  743.619995  743.619995
# 2017-01-06  795.260010  807.900024  792.203979  806.150024  806.150024
#
#               Volume    month   day_name
# Date
# 2005-01-06  20852067  January   Thursday
# 2006-01-06  35646914  January     Friday
# 2009-01-06  12898566  January    Tuesday
# ...

# %%
google["Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
subset=google[["Open", "High", "Low", "Close"]]
subset.plot(subplots= True, 
           layout=(2,2), figsize=(20,10), sharex=False)
# Out:
# array([[<Axes: xlabel='Date'>, <Axes: xlabel='Date'>],
#        [<Axes: xlabel='Date'>, <Axes: xlabel='Date'>]], dtype=object)

# %%
google.loc["2022"]["Open"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
google["quarter"]=google.index.quarter

# %%
google
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2004-08-19    49.813290    51.835709    47.800831    49.982655    49.982655
# 2004-08-20    50.316402    54.336334    50.062355    53.952770    53.952770
# 2004-08-23    55.168217    56.528118    54.321388    54.495735    54.495735
# 2004-08-24    55.412300    55.591629    51.591621    52.239197    52.239197
# 2004-08-25    52.284027    53.798351    51.746044    52.802086    52.802086
# ...                 ...          ...          ...          ...          ...
# 2022-05-16  2307.679932  2332.149902  2286.699951  2295.850098  2295.850098
# 2022-05-17  2344.550049  2344.550049  2306.750000  2334.030029  2334.030029
# 2022-05-18  2304.750000  2313.913086  2242.840088  2248.020020  2248.020020
# 2022-05-19  2236.820068  2271.750000  2209.360107  2214.909912  2214.909912
# 2022-05-20  2241.709961  2251.000000  2127.459961  2186.260010  2186.260010
#
#               Volume   month   day_name  quarter
# ...

# %%
google.asfreq("Q", method="bfill").plot()
# Out:
# C:\Users\guriv\AppData\Local\Temp\ipykernel_1252\2290622174.py:1: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   google.asfreq("Q", method="bfill").plot()
# <Axes: xlabel='Date'>

# %%
google.groupby("month")["Close"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='month'>

# %%
google.asfreq("Y")
# Out:
# C:\Users\guriv\AppData\Local\Temp\ipykernel_1252\1262818865.py:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   google.asfreq("Y")
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2004-12-31    99.243011    99.566795    95.920464    96.035034    96.035034
# 2005-12-31          NaN          NaN          NaN          NaN          NaN
# 2006-12-31          NaN          NaN          NaN          NaN          NaN
# 2007-12-31   347.980682   349.933350   344.000610   344.448914   344.448914
# 2008-12-31   151.532028   154.919327   150.739990   153.250580   153.250580
# 2009-12-31   311.208527   311.532288   308.832428   308.832428   308.832428
# 2010-12-31   297.255798   298.092682   294.909607   295.875977   295.875977
# 2011-12-31          NaN          NaN          NaN          NaN          NaN
# 2012-12-31   348.693024   353.958282   346.700470   352.369232   352.369232
# ...

# %%
#Down sampling
google["Close"].resample("W").mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
google["Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
google["Close"].resample("6h").interpolate(method="linear")
# Out:
# Date
# 2004-08-19 00:00:00      49.982655
# 2004-08-19 06:00:00      50.975184
# 2004-08-19 12:00:00      51.967713
# 2004-08-19 18:00:00      52.960241
# 2004-08-20 00:00:00      53.952770
#                           ...
# 2022-05-19 00:00:00    2214.909912
# 2022-05-19 06:00:00    2207.747436
# 2022-05-19 12:00:00    2200.584961
# 2022-05-19 18:00:00    2193.422486
# 2022-05-20 00:00:00    2186.260010
# Freq: 6h, Name: Close, Length: 25933, dtype: float64

# %%
google["Close"].rolling(window=3).mean()
# Out:
# Date
# 2004-08-19            NaN
# 2004-08-20            NaN
# 2004-08-23      52.810387
# 2004-08-24      53.562567
# 2004-08-25      53.179006
#                  ...
# 2022-05-16    2296.460043
# 2022-05-17    2320.063395
# 2022-05-18    2292.633382
# 2022-05-19    2265.653320
# 2022-05-20    2216.396647
# Name: Close, Length: 4471, dtype: float64

# %%
google["Open"].shift(1)
# Out:
# Date
# 2004-08-19            NaN
# 2004-08-20      49.813290
# 2004-08-23      50.316402
# 2004-08-24      55.168217
# 2004-08-25      55.412300
#                  ...
# 2022-05-16    2296.909912
# 2022-05-17    2307.679932
# 2022-05-18    2344.550049
# 2022-05-19    2304.750000
# 2022-05-20    2236.820068
# Name: Open, Length: 4471, dtype: float64

# %%
goog

# %%
"nitraipur".replace({"n":"i", "r":"n"})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 "nitraipur".replace({"n":"i", "r":"n"})
#
# TypeError: replace expected at least 2 arguments, got 1

# %%
pd.Timestamp("6th june 2015")-pd.Timestamp("6th june 2014")
# Out:
# Timedelta('365 days 00:00:00')
